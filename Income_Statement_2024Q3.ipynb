# %% [markdown]
# <a href="https://colab.research.google.com/github/fjusophia/fin_data/blob/main/Income_Statement_2024Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/fjusophia/fin_data/main/Income%20Statement%202024Q3.csv"

# %%
df = pd.read_csv(url, index_col=0)

# %%
print(df.head(5))
# Out:
#                Year/Month  Quarter Consolidated (Y/N)  Month Currency  \
# Company
# 1201 Wei Chuan    2024/09        3                  Y      9      NTD
# 1234 Hey Song     2024/09        3                  Y      9      NTD
#
#                Net Operating Revenue Operating Costs Gross Profit  \
# Company
# 1201 Wei Chuan            17,746,414      12,843,818    4,902,596
# 1234 Hey Song              7,975,741       5,558,144    2,417,597
#
#                 Affiliate Realized (Unrealized) Sales Profit  \
# Company
# 1201 Wei Chuan                                             0
# 1234 Hey Song                                              0
#
#                Realized Sales Gross Profit  ...  \
# Company                                     ...
# 1201 Wei Chuan                   4,902,596  ...
# 1234 Hey Song                    2,417,597  ...
#
#                Comprehensive Income Attributable to Non-Controlling Interests under Common Control  \
# Company
# ...

# %%
df.head(5)
# Out:
#                Year/Month  Quarter Consolidated (Y/N)  Month Currency  \
# Company
# 1201 Wei Chuan    2024/09        3                  Y      9      NTD
# 1234 Hey Song     2024/09        3                  Y      9      NTD
#
#                Net Operating Revenue Operating Costs Gross Profit  \
# Company
# 1201 Wei Chuan            17,746,414      12,843,818    4,902,596
# 1234 Hey Song              7,975,741       5,558,144    2,417,597
#
#                 Affiliate Realized (Unrealized) Sales Profit  \
# Company
# 1201 Wei Chuan                                             0
# 1234 Hey Song                                              0
#
#                Realized Sales Gross Profit  ...  \
# Company                                     ...
# 1201 Wei Chuan                   4,902,596  ...
# 1234 Hey Song                    2,417,597  ...
#
#                Comprehensive Income Attributable to Non-Controlling Interests under Common Control  \
# Company
# ...

# %%
df.columns
# Out:
# Index(['Year/Month', 'Quarter', 'Consolidated (Y/N)', 'Month', 'Currency',
#        'Net Operating Revenue', 'Operating Costs', 'Gross Profit',
#        'Affiliate Realized (Unrealized) Sales Profit',
#        'Realized Sales Gross Profit', 'Operating Expenses',
#        'Research and Development Expenses',
#        'Expected Credit Impairment (Loss) Benefit - Operating Expenses',
#        'Other Income and Expense Net', 'Operating Profit', 'Interest Income',
#        'Other Income', 'Other Gains and Losses', 'Financial Costs',
#        'Share of Equity Method Affiliate and Joint Venture Profit and Loss',
#        'Expected Credit Impairment (Loss) Benefit',
#        'Derecognition of Financial Assets Measured at Amortized Cost Net Gain or Loss',
#        'Financial Asset Reclassification Net Gain or Loss',
#        'Non-operating Income and Expense - Other',
#        'Non-operating Income and Expense', 'Profit Before Tax',
# ...
